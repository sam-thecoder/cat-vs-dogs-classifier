# %%
import os
import sys
import cv2

import random

import numpy as np

from tqdm import tqdm
import pickle

from keras.models import Sequential 
from keras.layers import Conv2D, MaxPooling2D 
from keras.layers import Activation, Dropout, Flatten, Dense

from keras.callbacks import TensorBoard, EarlyStopping, ModelCheckpoint

import matplotlib.pyplot as plt

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
os.listdir('data')
# Out:
# ['train', 'test', 'sample_submission.csv']

# %%
len(os.listdir('data/train'))
# Out:
# 25000

# %%
train_images = os.listdir('data/train')
test_images = os.listdir('data/test')

print(len(train_images))
print(len(test_images))
# Out:
# 25000
# 12500

# %%
train_images[:10]
# Out:
# ['cat.4213.jpg',
#  'cat.7203.jpg',
#  'dog.8250.jpg',
#  'dog.7907.jpg',
#  'dog.2318.jpg',
#  'cat.6480.jpg',
#  'dog.7973.jpg',
#  'dog.2225.jpg',
#  'dog.611.jpg',
#  'dog.5955.jpg']

# %%
test_images[:10]
# Out:
# ['1818.jpg',
#  '374.jpg',
#  '1681.jpg',
#  '2880.jpg',
#  '2001.jpg',
#  '11288.jpg',
#  '4282.jpg',
#  '7510.jpg',
#  '11638.jpg',
#  '8288.jpg']

# %%
test_images_data = []

for image in tqdm(test_images):
    image_data = cv2.imread('data/test/' + image)
    
    #Convert to GrayScale
    gray = cv2.cvtColor(image_data, cv2.COLOR_BGR2GRAY)
    
    #convert color from BGR to RGB
    #image_data = cv2.cvtColor(image_data, cv2.COLOR_BGR2RGB)
    
    image_data = cv2.resize(gray, (64, 64))
    
    #turn to only borders
    #edges = cv2.Canny(image_data, 150, 150)
    
    test_images_data.append(image_data)
# Out:
# 100%|██████████| 12500/12500 [07:25<00:00, 28.03it/s]

# %%
test_images_data = np.array(test_images_data)

# %%
image = cv2.imread('data/test/' + test_images[0], cv2.IMREAD_COLOR)

# %%
'data/test/'+test_images[0]
# Out:
# 'data/test/1818.jpg'

# %%
image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(image)
plt.show()

# %%
train_images_data = []
train_images_labels = []

random.shuffle(train_images)

for image in tqdm(train_images):
    image_data = cv2.imread('data/train/' + image)
    
    #Convert to GrayScale
    gray = cv2.cvtColor(image_data, cv2.COLOR_BGR2GRAY)
    
    #convert color from BGR to RGB
    #image_data = cv2.cvtColor(image_data, cv2.COLOR_BGR2RGB)
    
    image_data = cv2.resize(gray, (64, 64))
    
    #turn to only borders
    #edges = cv2.Canny(image_data, 150, 150)
    
    train_images_data.append(image_data)
    train_images_data.append(image_data[:, ::-1]) #flipped image
    
    
    if image.startswith('cat'):
        train_images_labels.append(0)
        train_images_labels.append(0)
        #train_images_labels.append([0, 1])
    else:
        train_images_labels.append(1)
        train_images_labels.append(1)
        #train_images_labels.append([1, 0])
# Out:
# 100%|██████████| 25000/25000 [08:48<00:00, 47.28it/s]

# %%
train_images_data = np.array(train_images_data)
train_images_labels = np.array(train_images_labels)

train_images_data = train_images_data.reshape([-1, 64, 64, 1])

# %%
pickle.dump(train_images_data, open('model_data/grayscale_train_images_data.pck', 'wb'))

# %%
pickle.dump(test_images_data, open('model_data/grayscale_test_images_data.pck', 'wb'))

# %%
pickle.dump(train_images_labels, open('model_data/grayscale_train_images_labels.pck', 'wb'))

# %%
model_name = 'grayscale_model_epochs_100_conv_5_by_5_dropout'

# %%
model = Sequential() 
model.add(Conv2D(64, (5, 5), input_shape=(64, 64, 1))) 
model.add(Activation('relu')) 
model.add(MaxPooling2D(pool_size=(2, 2))) 
  
model.add(Conv2D(32, (3, 3))) 
model.add(Activation('relu')) 
model.add(MaxPooling2D(pool_size=(2, 2))) 
  
model.add(Conv2D(16, (3, 3))) 
model.add(Activation('relu')) 
model.add(MaxPooling2D(pool_size=(2, 2))) 
  
model.add(Flatten()) 
model.add(Dense(50)) 
model.add(Activation('relu')) 
model.add(Dropout(0.5)) 
model.add(Dense(1)) 
model.add(Activation('sigmoid')) 

model.compile(loss='binary_crossentropy', 
              optimizer='adam', 
              metrics=['accuracy']) 

tensorboard = TensorBoard(log_dir="logs/{}".format(model_name))
early_stop = EarlyStopping(monitor='val_loss', patience=5)
checkpoint = ModelCheckpoint(filepath='model_data/' + model_name + '_checkpoint.h5', monitor='val_loss', 
                             save_best_only=True)

model.fit(train_images_data, train_images_labels, epochs=100, validation_split=0.2, 
          callbacks=[tensorboard, early_stop, checkpoint])
# Out:
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/100
# 40000/40000 [==============================] - 644s 16ms/step - loss: 0.7201 - acc: 0.5074 - val_loss: 0.6909 - val_acc: 0.5336
# Epoch 2/100
# 40000/40000 [==============================] - 646s 16ms/step - loss: 0.6917 - acc: 0.5051 - val_loss: 0.6888 - val_acc: 0.5508
# Epoch 3/100
# 40000/40000 [==============================] - 648s 16ms/step - loss: 0.6890 - acc: 0.5264 - val_loss: 0.6844 - val_acc: 0.5392
# Epoch 4/100
# 40000/40000 [==============================] - 652s 16ms/step - loss: 0.6851 - acc: 0.5356 - val_loss: 0.6831 - val_acc: 0.5496
# Epoch 5/100
# 40000/40000 [==============================] - 653s 16ms/step - loss: 0.6816 - acc: 0.5444 - val_loss: 0.6914 - val_acc: 0.5507
# Epoch 6/100
# 40000/40000 [==============================] - 654s 16ms/step - loss: 0.6803 - acc: 0.5494 - val_loss: 0.6783 - val_acc: 0.5664
# Epoch 7/100
# 40000/40000 [==============================] - 657s 16ms/step - loss: 0.6783 - acc: 0.5583 - val_loss: 0.6747 - val_acc: 0.5732
# Epoch 8/100
# 40000/40000 [==============================] - 658s 16ms/step - loss: 0.6684 - acc: 0.5835 - val_loss: 0.6601 - val_acc: 0.6109
# Epoch 9/100
# 40000/40000 [==============================] - 659s 16ms/step - loss: 0.6493 - acc: 0.6219 - val_loss: 0.6177 - val_acc: 0.6665
# Epoch 10/100
# 40000/40000 [==============================] - 660s 16ms/step - loss: 0.5874 - acc: 0.6938 - val_loss: 0.5494 - val_acc: 0.7281
# Epoch 11/100
# 40000/40000 [==============================] - 662s 17ms/step - loss: 0.5376 - acc: 0.7351 - val_loss: 0.5275 - val_acc: 0.7412
# Epoch 12/100
# 40000/40000 [==============================] - 663s 17ms/step - loss: 0.5046 - acc: 0.7567 - val_loss: 0.4864 - val_acc: 0.7656
# Epoch 13/100
# 40000/40000 [==============================] - 664s 17ms/step - loss: 0.4827 - acc: 0.7744 - val_loss: 0.4738 - val_acc: 0.7805
# Epoch 14/100
# 40000/40000 [==============================] - 666s 17ms/step - loss: 0.4601 - acc: 0.7855 - val_loss: 0.4794 - val_acc: 0.7728
# Epoch 15/100
# 40000/40000 [==============================] - 667s 17ms/step - loss: 0.4425 - acc: 0.7945 - val_loss: 0.4543 - val_acc: 0.7908
# Epoch 16/100
# 40000/40000 [==============================] - 668s 17ms/step - loss: 0.4307 - acc: 0.8025 - val_loss: 0.4502 - val_acc: 0.7966
# Epoch 17/100
# 40000/40000 [==============================] - 674s 17ms/step - loss: 0.4163 - acc: 0.8107 - val_loss: 0.4438 - val_acc: 0.7960
# Epoch 18/100
# 40000/40000 [==============================] - 670s 17ms/step - loss: 0.4035 - acc: 0.8167 - val_loss: 0.4261 - val_acc: 0.8073
# Epoch 19/100
# 40000/40000 [==============================] - 672s 17ms/step - loss: 0.3939 - acc: 0.8224 - val_loss: 0.4264 - val_acc: 0.8068
# Epoch 20/100
# 40000/40000 [==============================] - 673s 17ms/step - loss: 0.3779 - acc: 0.8305 - val_loss: 0.4355 - val_acc: 0.8129
# Epoch 21/100
# 40000/40000 [==============================] - 673s 17ms/step - loss: 0.3714 - acc: 0.8330 - val_loss: 0.4516 - val_acc: 0.8045
# Epoch 22/100
# 40000/40000 [==============================] - 674s 17ms/step - loss: 0.3618 - acc: 0.8383 - val_loss: 0.4240 - val_acc: 0.8120
# Epoch 23/100
# 40000/40000 [==============================] - 674s 17ms/step - loss: 0.3594 - acc: 0.8402 - val_loss: 0.4214 - val_acc: 0.8110
# Epoch 24/100
# 40000/40000 [==============================] - 676s 17ms/step - loss: 0.3439 - acc: 0.8469 - val_loss: 0.4432 - val_acc: 0.8058
# Epoch 25/100
# 40000/40000 [==============================] - 678s 17ms/step - loss: 0.3368 - acc: 0.8516 - val_loss: 0.4721 - val_acc: 0.7921
# Epoch 26/100
# 40000/40000 [==============================] - 679s 17ms/step - loss: 0.3342 - acc: 0.8507 - val_loss: 0.4255 - val_acc: 0.8159
# Epoch 27/100
# 40000/40000 [==============================] - 680s 17ms/step - loss: 0.3273 - acc: 0.8565 - val_loss: 0.4402 - val_acc: 0.8093
# Epoch 28/100
# 40000/40000 [==============================] - 681s 17ms/step - loss: 0.3238 - acc: 0.8560 - val_loss: 0.4338 - val_acc: 0.8146

# %%
#save the data as pickle files
#save the model
#run on test example images, about 10 to see classification

# %%
model.save('models/' + model_name + '.h5')
