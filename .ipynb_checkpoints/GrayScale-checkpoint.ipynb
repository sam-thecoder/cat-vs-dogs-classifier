# %%
import os
import sys
import cv2

import random

import numpy as np

from tqdm import tqdm
import pickle

from keras.models import Sequential 
from keras.layers import Conv2D, MaxPooling2D 
from keras.layers import Activation, Dropout, Flatten, Dense

from keras.callbacks import TensorBoard, EarlyStopping, ModelCheckpoint

import matplotlib.pyplot as plt

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
os.listdir('data')
# Out:
# ['sample_submission.csv', 'test', 'train']

# %%
len(os.listdir('data/train'))
# Out:
# 25000

# %%
train_images = os.listdir('data/train')
test_images = os.listdir('data/test')

print(len(train_images))
print(len(test_images))
# Out:
# 25000
# 12500

# %%
train_images[:10]
# Out:
# ['dog.3730.jpg',
#  'cat.8279.jpg',
#  'cat.7998.jpg',
#  'cat.6615.jpg',
#  'cat.9309.jpg',
#  'cat.2355.jpg',
#  'cat.476.jpg',
#  'cat.11387.jpg',
#  'cat.2401.jpg',
#  'cat.5022.jpg']

# %%
test_images[:10]
# Out:
# ['11522.jpg',
#  '10210.jpg',
#  '12040.jpg',
#  '4352.jpg',
#  '856.jpg',
#  '6162.jpg',
#  '12274.jpg',
#  '8091.jpg',
#  '3558.jpg',
#  '11500.jpg']

# %%
test_images_data = []

for image in tqdm(test_images):
    image_data = cv2.imread('data/test/' + image)
    
    #Convert to GrayScale
    gray = cv2.cvtColor(image_data, cv2.COLOR_BGR2GRAY)
    
    #convert color from BGR to RGB
    #image_data = cv2.cvtColor(image_data, cv2.COLOR_BGR2RGB)
    
    image_data = cv2.resize(gray, (64, 64))
    
    #turn to only borders
    #edges = cv2.Canny(image_data, 150, 150)
    
    test_images_data.append(image_data)
# Out:
# 100%|██████████| 12500/12500 [03:01<00:00, 68.72it/s]

# %%
test_images_data = np.array(test_images_data)

# %%
image = cv2.imread('data/test/' + test_images[0], cv2.COLOR_BGR2GRAY)

# %%
'data/test/'+test_images[0]
# Out:
# 'data/test/11522.jpg'

# %%
image = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(image, cmap='gray')
plt.show()

# %%
train_images_data = []
train_images_labels = []

random.shuffle(train_images)

for image in tqdm(train_images):
    image_data = cv2.imread('data/train/' + image)
    
    #Convert to GrayScale
    gray = cv2.cvtColor(image_data, cv2.COLOR_BGR2GRAY)
    
    #convert color from BGR to RGB
    #image_data = cv2.cvtColor(image_data, cv2.COLOR_BGR2RGB)
    
    image_data = cv2.resize(gray, (64, 64))
    
    #turn to only borders
    #edges = cv2.Canny(image_data, 150, 150)
    
    train_images_data.append(image_data)
    train_images_data.append(image_data[:, ::-1]) #flipped image
    
    
    if image.startswith('cat'):
        train_images_labels.append(0)
        train_images_labels.append(0)
        #train_images_labels.append([0, 1])
    else:
        train_images_labels.append(1)
        train_images_labels.append(1)
        #train_images_labels.append([1, 0])
# Out:
# 100%|██████████| 25000/25000 [06:34<00:00, 63.45it/s]

# %%
train_images_data = np.array(train_images_data)
train_images_labels = np.array(train_images_labels)

train_images_data = train_images_data.reshape([-1, 64, 64, 1])

# %%
pickle.dump(train_images_data, open('model_data/grayscale_train_images_data.pck', 'wb'))

# %%
pickle.dump(test_images_data, open('model_data/grayscale_test_images_data.pck', 'wb'))

# %%
pickle.dump(train_images_labels, open('model_data/grayscale_train_images_labels.pck', 'wb'))

# %%
model_name = 'grayscale_model_epochs_100_conv_5_by_5_dropout'

# %%
model = Sequential() 
model.add(Conv2D(64, (5, 5), input_shape=(64, 64, 1))) 
model.add(Activation('relu')) 
model.add(MaxPooling2D(pool_size=(2, 2))) 
  
model.add(Conv2D(32, (3, 3))) 
model.add(Activation('relu')) 
model.add(MaxPooling2D(pool_size=(2, 2))) 
  
model.add(Conv2D(16, (3, 3))) 
model.add(Activation('relu')) 
model.add(MaxPooling2D(pool_size=(2, 2))) 
  
model.add(Flatten()) 
model.add(Dense(50)) 
model.add(Activation('relu')) 
model.add(Dropout(0.5)) 
model.add(Dense(1)) 
model.add(Activation('sigmoid')) 

model.compile(loss='binary_crossentropy', 
              optimizer='adam', 
              metrics=['accuracy']) 

tensorboard = TensorBoard(log_dir="logs/{}".format(model_name))
early_stop = EarlyStopping(monitor='val_loss', patience=5)
checkpoint = ModelCheckpoint(filepath='model_data/' + model_name + '_checkpoint.h5', monitor='val_loss', 
                             save_best_only=True)

model.fit(train_images_data, train_images_labels, epochs=100, validation_split=0.2, 
          callbacks=[tensorboard, early_stop, checkpoint])
# Out:
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/100
# 40000/40000 [==============================] - 791s 20ms/step - loss: 0.6990 - accuracy: 0.5371 - val_loss: 0.6851 - val_accuracy: 0.5466
# Epoch 2/100
# 40000/40000 [==============================] - 785s 20ms/step - loss: 0.6836 - accuracy: 0.5497 - val_loss: 0.6834 - val_accuracy: 0.5524
# Epoch 3/100
# 40000/40000 [==============================] - 843s 21ms/step - loss: 0.6658 - accuracy: 0.5889 - val_loss: 0.6419 - val_accuracy: 0.6262
# Epoch 4/100
# 40000/40000 [==============================] - 771s 19ms/step - loss: 0.6386 - accuracy: 0.6357 - val_loss: 0.6146 - val_accuracy: 0.6770
# Epoch 5/100
# 40000/40000 [==============================] - 761s 19ms/step - loss: 0.6199 - accuracy: 0.6607 - val_loss: 0.6204 - val_accuracy: 0.6553
# Epoch 6/100
# 40000/40000 [==============================] - 724s 18ms/step - loss: 0.6015 - accuracy: 0.6771 - val_loss: 0.5947 - val_accuracy: 0.6893
# Epoch 7/100
# 40000/40000 [==============================] - 746s 19ms/step - loss: 0.5829 - accuracy: 0.6952 - val_loss: 0.5848 - val_accuracy: 0.6970
# Epoch 8/100
# 40000/40000 [==============================] - 738s 18ms/step - loss: 0.5669 - accuracy: 0.7105 - val_loss: 0.5685 - val_accuracy: 0.7097
# Epoch 9/100
# 40000/40000 [==============================] - 761s 19ms/step - loss: 0.5507 - accuracy: 0.7227 - val_loss: 0.5389 - val_accuracy: 0.7287
# Epoch 10/100
# 40000/40000 [==============================] - 664s 17ms/step - loss: 0.5366 - accuracy: 0.7349 - val_loss: 0.5833 - val_accuracy: 0.6935
# Epoch 11/100
# 40000/40000 [==============================] - 691s 17ms/step - loss: 0.5249 - accuracy: 0.7405 - val_loss: 0.5281 - val_accuracy: 0.7366
# Epoch 12/100
# 40000/40000 [==============================] - 678s 17ms/step - loss: 0.5135 - accuracy: 0.7502 - val_loss: 0.5173 - val_accuracy: 0.7490
# Epoch 13/100
# 40000/40000 [==============================] - 749s 19ms/step - loss: 0.5052 - accuracy: 0.7544 - val_loss: 0.5137 - val_accuracy: 0.7535
# Epoch 14/100
# 40000/40000 [==============================] - 690s 17ms/step - loss: 0.4921 - accuracy: 0.7629 - val_loss: 0.5148 - val_accuracy: 0.7481
# Epoch 15/100
# 40000/40000 [==============================] - 677s 17ms/step - loss: 0.4848 - accuracy: 0.7660 - val_loss: 0.5305 - val_accuracy: 0.7361
# Epoch 16/100
# 40000/40000 [==============================] - 579s 14ms/step - loss: 0.4755 - accuracy: 0.7721 - val_loss: 0.5079 - val_accuracy: 0.7544
# Epoch 17/100
# 40000/40000 [==============================] - 519s 13ms/step - loss: 0.4665 - accuracy: 0.7796 - val_loss: 0.5132 - val_accuracy: 0.7534
# Epoch 18/100
# 40000/40000 [==============================] - 517s 13ms/step - loss: 0.4580 - accuracy: 0.7847 - val_loss: 0.4958 - val_accuracy: 0.7649
# Epoch 19/100
# 40000/40000 [==============================] - 517s 13ms/step - loss: 0.4453 - accuracy: 0.7897 - val_loss: 0.4908 - val_accuracy: 0.7697
# Epoch 20/100
# 40000/40000 [==============================] - 516s 13ms/step - loss: 0.4436 - accuracy: 0.7915 - val_loss: 0.4950 - val_accuracy: 0.7637
# Epoch 21/100
# 40000/40000 [==============================] - 516s 13ms/step - loss: 0.4337 - accuracy: 0.7982 - val_loss: 0.5034 - val_accuracy: 0.7677
# Epoch 22/100
# 40000/40000 [==============================] - 515s 13ms/step - loss: 0.4293 - accuracy: 0.7992 - val_loss: 0.4917 - val_accuracy: 0.7735
# Epoch 23/100
# 40000/40000 [==============================] - 515s 13ms/step - loss: 0.4224 - accuracy: 0.8032 - val_loss: 0.4949 - val_accuracy: 0.7687
# Epoch 24/100
# 40000/40000 [==============================] - 516s 13ms/step - loss: 0.4165 - accuracy: 0.8064 - val_loss: 0.4838 - val_accuracy: 0.7769
# Epoch 25/100
# 40000/40000 [==============================] - 516s 13ms/step - loss: 0.4039 - accuracy: 0.8125 - val_loss: 0.5061 - val_accuracy: 0.7669
# Epoch 26/100
# 40000/40000 [==============================] - 516s 13ms/step - loss: 0.4024 - accuracy: 0.8135 - val_loss: 0.5120 - val_accuracy: 0.7735
# Epoch 27/100
# 40000/40000 [==============================] - 515s 13ms/step - loss: 0.3953 - accuracy: 0.8149 - val_loss: 0.5330 - val_accuracy: 0.7752
# Epoch 28/100
# 40000/40000 [==============================] - 515s 13ms/step - loss: 0.3923 - accuracy: 0.8185 - val_loss: 0.5187 - val_accuracy: 0.7760
# Epoch 29/100
# 40000/40000 [==============================] - 516s 13ms/step - loss: 0.3861 - accuracy: 0.8217 - val_loss: 0.5139 - val_accuracy: 0.7735

# %%
model.save('models/' + model_name + '.h5')
